# %%
import sys
sys.path.append('../')
from CMRx4DFlowMaskGeneration import *
from Utils import *
from einops import rearrange
import matplotlib.pyplot as plt

# %%
# Read one subject/case from a directory containing the corresponding .mat files
data_dir = '/mnt/nas/nas3/openData/rawdata/4dFlow/ChallengeData/DemoData'

# `load_mat` takes the .mat file path and variable name (`key`) as input.
# It returns a lazy HDF5-like handle (h5py-style): data is not loaded into memory
# until you index it.
kdata_full = load_mat(data_dir + '/kdata_full.mat', key='kdata_full')
coilmap    = load_mat(data_dir + '/coilmap.mat',    key='coilmap')
segmask    = load_mat(data_dir + '/segmask.mat',    key='segmask')
params     = read_params_csv(data_dir + '/params.csv')

# Use [()] to materialize the entire dataset into RAM as a NumPy array.
kdata_full = kdata_full[()]
coilmap    = coilmap[()]
segmask    = segmask[()]

Nv, Nt, Nc, SPE, PE, FE = kdata_full.shape

VENC = params['VENC']
VOrder = params['venc_order']

# %%
img = np.sum(k2i_numpy(kdata_full, ax=[-1, -2, -3]) * np.conj(coilmap), axis=-4)

# %%
usrate = 10  # Desired undersampling factor (e.g., 10x)

# Target number of sampled k-space locations per 2D (PE, SPE) frame
total_points = PE * SPE // usrate

# fun_mask_gen_2d expects mask_size = (width, height) = (PE, SPE)
mask_size = (PE, SPE)

# Gaussian sampling density parameters:
sigma_x = PE / 5
sigma_y = SPE / 5

# Generate one undersampling mask per time frame.
# Output shape: (SPE, PE, Nt)
masks_spe_pe_t = fun_mask_gen_2d(
    mask_size=mask_size,
    total_points=total_points,
    pattern_num=Nt,
    sigma_x=sigma_x,
    sigma_y=sigma_y,
)

# Reshape to the expected tensor layout:
# (SPE, PE, Nt) -> (1, Nt, 1, SPE, PE, 1)
usmask = rearrange(masks_spe_pe_t, "spe pe t -> 1 t 1 spe pe 1")

# Empirical undersampling factor from the sampling density:
# mean(usmask) is the fraction of sampled points, so 1/mean is the effective acceleration.
actual_usrate = 1.0 / np.mean(usmask)
print(f"Mask shape: {usmask.shape}, Actual undersampling rate: {actual_usrate:.2f}x")

# --- Visualization ---
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle(
    f"Undersampling Mask (Target: {usrate}x, Actual: {actual_usrate:.2f}x)",
    fontsize=14,
    fontweight="bold",
)

# Panel 1: a single time-frame mask, displayed as (PE, SPE) for readability
im0 = axes[0].imshow(usmask[0, 0, 0, :, :, 0].T, cmap="gray")
axes[0].set_xlabel("PE", fontsize=12)
axes[0].set_ylabel("SPE", fontsize=12)
axes[0].set_title("Single-Frame Mask", fontsize=12)
plt.colorbar(im0, ax=axes[0], fraction=0.046)

# Panel 2: temporal evolution for a fixed SPE line (middle SPE index).
# Shows (PE vs time) sampling pattern at that SPE location.
im1 = axes[1].imshow(usmask[0, :, 0, SPE // 2, :, 0].T, cmap="gray")
axes[1].set_xlabel("PE", fontsize=12)
axes[1].set_ylabel("Time frame (Nt)", fontsize=12)
axes[1].set_title(f"Temporal Variation (fixed SPE={SPE // 2})", fontsize=12)
plt.colorbar(im1, ax=axes[1], fraction=0.046)

plt.tight_layout()
plt.show()
# Out:
# Mask shape: (1, 12, 1, 39, 160, 1), Actual undersampling rate: 10.00x

# %% [markdown]
# The image \(X\) can be reconstructed from undersampled multi-coil k-space measurements \(y\) by solving a regularized inverse problem:
#
# $$
# \hat{X}
# = \arg\min_{X}\;
# \frac{1}{2}\bigl\lVert \mathcal{A}(X) - y \bigr\rVert_2^2
# \;+\;
# \lambda_{\mathrm{llr}} \sum_{i\in\Omega} \bigl\lVert \mathcal{P}_i(X) \bigr\rVert_*
# \;+\;
# \lambda_{\mathrm{TV}} \,\lVert X \rVert_{\mathrm{TV}}.
# $$
#
# **Symbol definitions:**
# - $\hat{X}$: The reconstructed image (`img_csllr`).
# - $y$: Undersampled multi-coil k-space measurements.
# - $\mathcal{A}(\cdot)$: The forward encoding operator that maps an image $X$ to undersampled multi-coil k-space. In this demo, it is the composition of coil sensitivity modulation, FFT, and application of the undersampling mask, i.e.,
#   $$
#   \mathcal{A}(X) = \mathbf{U}\mathcal{F}\mathbf{C}X,
#   $$
#   where $\mathbf{C}$ applies the coil sensitivity maps, $\mathcal{F}$ is the FFT, and $\mathbf{U}$ is the undersampling mask.
# - $\lambda_{\mathrm{llr}}$: Weight for locally low-rank (LLR) regularization.
# - $\Omega$: Index set of local blocks/patches over which LLR is enforced.
# - $\mathcal{P}_i(\cdot)$: Patch/block extraction (and reshaping) operator that maps $X$ to the $i$-th local matrix.
# - $\lVert \cdot \rVert_*$: Nuclear norm.
# - $\lambda_{\mathrm{TV}}$: Weight for total variation (TV) regularization.
# - $\lVert X \rVert_{\mathrm{TV}}$: TV seminorm of $X$.

# %%
kdata_us = kdata_full * usmask
ksp = rearrange(kdata_us, 'nv nt nc spe pe fe -> nv nc nt fe pe spe')
coils = rearrange(coilmap, 'nc spe pe fe-> nc 1 fe pe spe')
# In this demo, we only use LLR regularization; therefore, we set lamb_tv = 0.0 (i.e., TV regularization is disabled).
lamb_tv = 0.0
lamb_llr = 0.5 
img_csllr = CS_LLR(lamb_tv, lamb_llr, ksp, coils, seg=True, dev='cuda:0')
img_csllr = rearrange(img_csllr, 'nv nt fe pe spe -> nv nt spe pe fe')
# Out:
# /home/caory/miniconda3/envs/ryy/lib/python3.10/site-packages/torch/cuda/memory.py:491: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# /localhome/caory/CMRx4DFlow2026/CMRx4DFlowReconDemo/Utils/CS_LLR_utils.py:147: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   bsz = torch.tensor(bsz, dtype=torch.float32)
# /localhome/caory/CMRx4DFlow2026/CMRx4DFlowReconDemo/Utils/CS_LLR_utils.py:148: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(bsz * torch.ceil(imsz / bsz), dtype=torch.long)
# it 0 cost=99083.0078125 data_cost 75416.96875 nuclear_cost 47332.07421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.237
# it 1 cost=86482.890625 data_cost 62022.6171875 nuclear_cost 48920.54296875
# 	time_data=0.004 time_regs=0.001 time_prox=0.183
# it 2 cost=74982.578125 data_cost 49641.48828125 nuclear_cost 50682.171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.192
# it 3 cost=65569.796875 data_cost 39159.7421875 nuclear_cost 52820.1015625
# 	time_data=0.004 time_regs=0.001 time_prox=0.138
# it 4 cost=58188.8125 data_cost 30827.107421875 nuclear_cost 54723.40625
# 	time_data=0.004 time_regs=0.001 time_prox=0.128
# it 5 cost=52595.640625 data_cost 24457.599609375 nuclear_cost 56276.08203125
# 	time_data=0.003 time_regs=0.001 time_prox=0.211
# it 6 cost=47868.3046875 data_cost 19692.205078125 nuclear_cost 56352.203125
# 	time_data=0.004 time_regs=0.001 time_prox=0.215
# it 7 cost=45594.90625 data_cost 16231.291015625 nuclear_cost 58727.2265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.198
# it 8 cost=42559.421875 data_cost 13605.263671875 nuclear_cost 57908.3125
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 9 cost=40704.828125 data_cost 11645.791015625 nuclear_cost 58118.078125
# 	time_data=0.004 time_regs=0.001 time_prox=0.233
# it 10 cost=38931.1015625 data_cost 10138.646484375 nuclear_cost 57584.90625
# 	time_data=0.003 time_regs=0.001 time_prox=0.200
# it 11 cost=37679.1171875 data_cost 8945.314453125 nuclear_cost 57467.6015625
# 	time_data=0.004 time_regs=0.002 time_prox=0.218
# it 12 cost=36008.140625 data_cost 7959.806640625 nuclear_cost 56096.671875
# 	time_data=0.004 time_regs=0.001 time_prox=0.219
# it 13 cost=34867.828125 data_cost 7193.587890625 nuclear_cost 55348.484375
# 	time_data=0.003 time_regs=0.001 time_prox=0.215
# it 14 cost=34328.54296875 data_cost 6532.330078125 nuclear_cost 55592.42578125
# 	time_data=0.004 time_regs=0.001 time_prox=0.158
# it 15 cost=32673.384765625 data_cost 5920.74462890625 nuclear_cost 53505.28125
# 	time_data=0.003 time_regs=0.001 time_prox=0.143
# it 16 cost=31517.509765625 data_cost 5441.955078125 nuclear_cost 52151.109375
# 	time_data=0.004 time_regs=0.001 time_prox=0.149
# it 17 cost=31416.16015625 data_cost 5046.4482421875 nuclear_cost 52739.421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.183
# it 18 cost=31045.07421875 data_cost 4652.396484375 nuclear_cost 52785.35546875
# 	time_data=0.004 time_regs=0.001 time_prox=0.182
# it 19 cost=29566.431640625 data_cost 4294.322265625 nuclear_cost 50544.21875
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 20 cost=29249.2734375 data_cost 4004.186767578125 nuclear_cost 50490.171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.175
# it 21 cost=27712.28515625 data_cost 3754.000244140625 nuclear_cost 47916.5703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.177
# it 22 cost=27429.974609375 data_cost 3546.61572265625 nuclear_cost 47766.71875
# 	time_data=0.003 time_regs=0.001 time_prox=0.256
# it 23 cost=27016.99609375 data_cost 3384.42724609375 nuclear_cost 47265.13671875
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 24 cost=26908.0 data_cost 3177.353271484375 nuclear_cost 47461.29296875
# 	time_data=0.004 time_regs=0.001 time_prox=0.248
# it 25 cost=26420.818359375 data_cost 2977.302734375 nuclear_cost 46887.03125
# 	time_data=0.003 time_regs=0.001 time_prox=0.260
# it 26 cost=25561.46875 data_cost 2804.1357421875 nuclear_cost 45514.6640625
# 	time_data=0.007 time_regs=0.002 time_prox=0.243
# it 27 cost=25445.87890625 data_cost 2666.89111328125 nuclear_cost 45557.9765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 28 cost=24645.369140625 data_cost 2503.43994140625 nuclear_cost 44283.859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.257
# it 29 cost=24606.38671875 data_cost 2387.126220703125 nuclear_cost 44438.51953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 30 cost=24034.828125 data_cost 2278.35400390625 nuclear_cost 43512.94921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 31 cost=24000.33203125 data_cost 2183.672607421875 nuclear_cost 43633.3203125
# 	time_data=0.003 time_regs=0.001 time_prox=0.258
# it 32 cost=24147.263671875 data_cost 2097.447021484375 nuclear_cost 44099.6328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.187
# it 33 cost=23182.89453125 data_cost 2009.6844482421875 nuclear_cost 42346.421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.191
# it 34 cost=23436.197265625 data_cost 1940.4427490234375 nuclear_cost 42991.5078125
# 	time_data=0.004 time_regs=0.001 time_prox=0.123
# it 35 cost=23048.36328125 data_cost 1872.81787109375 nuclear_cost 42351.08984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.123
# it 36 cost=22634.314453125 data_cost 1818.4913330078125 nuclear_cost 41631.64453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.143
# it 37 cost=22633.140625 data_cost 1762.8828125 nuclear_cost 41740.515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.148
# it 38 cost=22297.34375 data_cost 1696.942138671875 nuclear_cost 41200.8046875
# 	time_data=0.004 time_regs=0.001 time_prox=0.192
# it 39 cost=22371.689453125 data_cost 1651.4078369140625 nuclear_cost 41440.5625
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 40 cost=22162.392578125 data_cost 1586.512939453125 nuclear_cost 41151.7578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.209
# it 41 cost=22006.53515625 data_cost 1538.510986328125 nuclear_cost 40936.046875
# 	time_data=0.004 time_regs=0.001 time_prox=0.222
# it 42 cost=21721.857421875 data_cost 1496.04248046875 nuclear_cost 40451.62890625
# 	time_data=0.004 time_regs=0.001 time_prox=0.206
# it 43 cost=21737.576171875 data_cost 1464.579345703125 nuclear_cost 40545.9921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.207
# it 44 cost=21742.71484375 data_cost 1435.2178955078125 nuclear_cost 40614.9921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.219
# it 45 cost=21733.970703125 data_cost 1412.0347900390625 nuclear_cost 40643.87109375
# 	time_data=0.004 time_regs=0.001 time_prox=0.209
# it 46 cost=21506.04296875 data_cost 1389.2578125 nuclear_cost 40233.5703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.215
# it 47 cost=21475.236328125 data_cost 1369.7730712890625 nuclear_cost 40210.92578125
# 	time_data=0.004 time_regs=0.001 time_prox=0.237
# it 48 cost=21349.61328125 data_cost 1355.4600830078125 nuclear_cost 39988.3046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.182
# it 49 cost=21452.056640625 data_cost 1343.755615234375 nuclear_cost 40216.6015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.179
# it 50 cost=21087.4453125 data_cost 1334.031494140625 nuclear_cost 39506.828125
# 	time_data=0.004 time_regs=0.001 time_prox=0.187
# it 51 cost=21100.171875 data_cost 1321.129638671875 nuclear_cost 39558.0859375
# 	time_data=0.004 time_regs=0.001 time_prox=0.176
# it 52 cost=21257.947265625 data_cost 1314.88427734375 nuclear_cost 39886.125
# 	time_data=0.003 time_regs=0.001 time_prox=0.169
# it 53 cost=21360.708984375 data_cost 1309.5347900390625 nuclear_cost 40102.34765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.169
# it 54 cost=21073.083984375 data_cost 1304.9296875 nuclear_cost 39536.30859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.176
# it 55 cost=21087.45703125 data_cost 1304.68798828125 nuclear_cost 39565.5390625
# 	time_data=0.004 time_regs=0.001 time_prox=0.187
# it 56 cost=21324.3359375 data_cost 1301.107177734375 nuclear_cost 40046.45703125
# 	time_data=0.004 time_regs=0.001 time_prox=0.180
# it 57 cost=21391.88671875 data_cost 1300.3958740234375 nuclear_cost 40182.98046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 58 cost=20965.009765625 data_cost 1298.732177734375 nuclear_cost 39332.5546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 59 cost=21271.876953125 data_cost 1298.3800048828125 nuclear_cost 39946.9921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 60 cost=21325.087890625 data_cost 1300.5164794921875 nuclear_cost 40049.14453125
# 	time_data=0.004 time_regs=0.001 time_prox=0.194
# it 61 cost=20876.20703125 data_cost 1300.353759765625 nuclear_cost 39151.70703125
# 	time_data=0.004 time_regs=0.001 time_prox=0.181
# it 62 cost=21049.267578125 data_cost 1301.700927734375 nuclear_cost 39495.1328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 63 cost=21344.130859375 data_cost 1301.275146484375 nuclear_cost 40085.7109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.161
# it 64 cost=21308.724609375 data_cost 1300.072998046875 nuclear_cost 40017.3046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.115
# it 65 cost=21194.638671875 data_cost 1302.735595703125 nuclear_cost 39783.8046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.136
# it 66 cost=20991.654296875 data_cost 1304.161865234375 nuclear_cost 39374.984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.140
# it 67 cost=21037.19921875 data_cost 1303.7021484375 nuclear_cost 39466.9921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.138
# it 68 cost=21292.44921875 data_cost 1304.7615966796875 nuclear_cost 39975.375
# 	time_data=0.004 time_regs=0.001 time_prox=0.140
# it 69 cost=21160.662109375 data_cost 1306.8416748046875 nuclear_cost 39707.640625
# 	time_data=0.004 time_regs=0.001 time_prox=0.141
# Elapsed 14.107531785964966
# Mem:  763.03076171875 1365.87890625 602.84814453125
# it 0 cost=98336.109375 data_cost 74786.2265625 nuclear_cost 47099.7578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.235
# it 1 cost=85843.4453125 data_cost 61563.1015625 nuclear_cost 48560.69140625
# 	time_data=0.004 time_regs=0.001 time_prox=0.194
# it 2 cost=74868.7421875 data_cost 49336.18359375 nuclear_cost 51065.12109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.178
# it 3 cost=65373.60546875 data_cost 38964.3359375 nuclear_cost 52818.5390625
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 4 cost=57571.9296875 data_cost 30730.146484375 nuclear_cost 53683.5703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.166
# it 5 cost=51793.90625 data_cost 24433.064453125 nuclear_cost 54721.6875
# 	time_data=0.003 time_regs=0.001 time_prox=0.136
# it 6 cost=48159.7890625 data_cost 19787.435546875 nuclear_cost 56744.7109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.133
# it 7 cost=45452.296875 data_cost 16285.6259765625 nuclear_cost 58333.34375
# 	time_data=0.003 time_regs=0.001 time_prox=0.152
# it 8 cost=42913.828125 data_cost 13648.984375 nuclear_cost 58529.6875
# 	time_data=0.004 time_regs=0.001 time_prox=0.153
# it 9 cost=40760.65625 data_cost 11670.2392578125 nuclear_cost 58180.8359375
# 	time_data=0.004 time_regs=0.001 time_prox=0.156
# it 10 cost=39655.60546875 data_cost 10164.4873046875 nuclear_cost 58982.234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.143
# it 11 cost=37900.8203125 data_cost 8938.302734375 nuclear_cost 57925.0390625
# 	time_data=0.003 time_regs=0.001 time_prox=0.144
# it 12 cost=36257.30078125 data_cost 7957.10693359375 nuclear_cost 56600.38671875
# 	time_data=0.004 time_regs=0.001 time_prox=0.143
# it 13 cost=34945.25390625 data_cost 7184.72705078125 nuclear_cost 55521.0546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.167
# it 14 cost=34672.34375 data_cost 6566.16748046875 nuclear_cost 56212.3515625
# 	time_data=0.007 time_regs=0.001 time_prox=0.169
# it 15 cost=33038.47265625 data_cost 5987.2177734375 nuclear_cost 54102.51171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 16 cost=31911.66015625 data_cost 5508.59716796875 nuclear_cost 52806.125
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 17 cost=31461.560546875 data_cost 5124.83447265625 nuclear_cost 52673.453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 18 cost=29870.6015625 data_cost 4736.18359375 nuclear_cost 50268.8359375
# 	time_data=0.003 time_regs=0.001 time_prox=0.195
# it 19 cost=30453.7890625 data_cost 4462.9130859375 nuclear_cost 51981.75
# 	time_data=0.004 time_regs=0.001 time_prox=0.174
# it 20 cost=29380.703125 data_cost 4140.6123046875 nuclear_cost 50480.1796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.198
# it 21 cost=28032.59765625 data_cost 3863.0673828125 nuclear_cost 48339.05859375
# 	time_data=0.006 time_regs=0.002 time_prox=0.195
# it 22 cost=27716.234375 data_cost 3636.587646484375 nuclear_cost 48159.29296875
# 	time_data=0.006 time_regs=0.002 time_prox=0.194
# it 23 cost=27719.96484375 data_cost 3449.31884765625 nuclear_cost 48541.29296875
# 	time_data=0.007 time_regs=0.002 time_prox=0.191
# it 24 cost=26484.994140625 data_cost 3249.351318359375 nuclear_cost 46471.28515625
# 	time_data=0.004 time_regs=0.002 time_prox=0.171
# it 25 cost=25715.23828125 data_cost 3095.133056640625 nuclear_cost 45240.2109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.182
# it 26 cost=25602.2109375 data_cost 2962.908447265625 nuclear_cost 45278.60546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.178
# it 27 cost=25587.341796875 data_cost 2827.88037109375 nuclear_cost 45518.921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.188
# it 28 cost=25064.189453125 data_cost 2685.02490234375 nuclear_cost 44758.328125
# 	time_data=0.005 time_regs=0.002 time_prox=0.115
# it 29 cost=25057.189453125 data_cost 2540.251220703125 nuclear_cost 45033.875
# 	time_data=0.003 time_regs=0.001 time_prox=0.112
# it 30 cost=24435.05078125 data_cost 2413.16064453125 nuclear_cost 44043.78125
# 	time_data=0.003 time_regs=0.001 time_prox=0.112
# it 31 cost=24112.97265625 data_cost 2318.408203125 nuclear_cost 43589.12890625
# 	time_data=0.003 time_regs=0.001 time_prox=0.113
# it 32 cost=24039.767578125 data_cost 2227.329833984375 nuclear_cost 43624.875
# 	time_data=0.003 time_regs=0.001 time_prox=0.123
# it 33 cost=23664.498046875 data_cost 2128.335693359375 nuclear_cost 43072.32421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 34 cost=23704.14453125 data_cost 2026.333251953125 nuclear_cost 43355.62109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 35 cost=23102.66796875 data_cost 1944.491455078125 nuclear_cost 42316.3515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 36 cost=22841.994140625 data_cost 1887.01708984375 nuclear_cost 41909.953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 37 cost=22689.94921875 data_cost 1839.378173828125 nuclear_cost 41701.140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 38 cost=22469.197265625 data_cost 1794.80078125 nuclear_cost 41348.79296875
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 39 cost=22729.068359375 data_cost 1744.48388671875 nuclear_cost 41969.16796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 40 cost=22391.73828125 data_cost 1703.59033203125 nuclear_cost 41376.296875
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 41 cost=22058.974609375 data_cost 1666.7867431640625 nuclear_cost 40784.375
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 42 cost=21999.0234375 data_cost 1639.2923583984375 nuclear_cost 40719.4609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 43 cost=21552.435546875 data_cost 1609.282470703125 nuclear_cost 39886.3046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 44 cost=21705.333984375 data_cost 1589.921875 nuclear_cost 40230.82421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 45 cost=22230.244140625 data_cost 1568.6519775390625 nuclear_cost 41323.18359375
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 46 cost=21556.45703125 data_cost 1544.4407958984375 nuclear_cost 40024.03125
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 47 cost=21349.724609375 data_cost 1530.2513427734375 nuclear_cost 39638.9453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 48 cost=21712.427734375 data_cost 1519.700927734375 nuclear_cost 40385.453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 49 cost=21882.8359375 data_cost 1498.7508544921875 nuclear_cost 40768.171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 50 cost=21299.974609375 data_cost 1481.8966064453125 nuclear_cost 39636.15625
# 	time_data=0.003 time_regs=0.001 time_prox=0.180
# it 51 cost=21853.46484375 data_cost 1472.6044921875 nuclear_cost 40761.71875
# 	time_data=0.003 time_regs=0.001 time_prox=0.131
# it 52 cost=21872.330078125 data_cost 1465.28125 nuclear_cost 40814.09765625
# 	time_data=0.004 time_regs=0.001 time_prox=0.119
# it 53 cost=21608.76171875 data_cost 1454.5509033203125 nuclear_cost 40308.421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.128
# it 54 cost=21658.3671875 data_cost 1451.6685791015625 nuclear_cost 40413.3984375
# 	time_data=0.004 time_regs=0.001 time_prox=0.126
# it 55 cost=21689.248046875 data_cost 1437.118408203125 nuclear_cost 40504.2578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.131
# it 56 cost=21516.408203125 data_cost 1432.6739501953125 nuclear_cost 40167.46875
# 	time_data=0.003 time_regs=0.001 time_prox=0.139
# it 57 cost=21370.669921875 data_cost 1422.1356201171875 nuclear_cost 39897.0703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.136
# it 58 cost=21531.53125 data_cost 1414.736572265625 nuclear_cost 40233.58984375
# 	time_data=0.004 time_regs=0.001 time_prox=0.133
# it 59 cost=21251.89453125 data_cost 1412.38232421875 nuclear_cost 39679.0234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.141
# it 60 cost=21759.3125 data_cost 1413.750732421875 nuclear_cost 40691.125
# 	time_data=0.004 time_regs=0.001 time_prox=0.173
# it 61 cost=21298.46875 data_cost 1414.38671875 nuclear_cost 39768.1640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.180
# it 62 cost=21519.46875 data_cost 1420.4462890625 nuclear_cost 40198.046875
# 	time_data=0.004 time_regs=0.001 time_prox=0.181
# it 63 cost=21605.4765625 data_cost 1425.2269287109375 nuclear_cost 40360.5
# 	time_data=0.003 time_regs=0.001 time_prox=0.194
# it 64 cost=21510.09765625 data_cost 1432.7081298828125 nuclear_cost 40154.77734375
# 	time_data=0.004 time_regs=0.001 time_prox=0.182
# it 65 cost=21435.669921875 data_cost 1439.0450439453125 nuclear_cost 39993.25
# 	time_data=0.003 time_regs=0.001 time_prox=0.180
# it 66 cost=21647.353515625 data_cost 1444.8961181640625 nuclear_cost 40404.9140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 67 cost=21376.734375 data_cost 1445.1055908203125 nuclear_cost 39863.2578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 68 cost=21222.998046875 data_cost 1450.595458984375 nuclear_cost 39544.8046875
# 	time_data=0.004 time_regs=0.001 time_prox=0.172
# it 69 cost=21760.82421875 data_cost 1453.9461669921875 nuclear_cost 40613.7578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# Elapsed 11.878790855407715
# Mem:  763.03076171875 1365.87890625 602.84814453125
# it 0 cost=98438.296875 data_cost 74936.6640625 nuclear_cost 47003.265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.149
# it 1 cost=85945.671875 data_cost 61721.51953125 nuclear_cost 48448.3046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.119
# it 2 cost=75067.390625 data_cost 49492.8984375 nuclear_cost 51148.9765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.131
# it 3 cost=65426.3046875 data_cost 39107.75 nuclear_cost 52637.109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.140
# it 4 cost=58143.375 data_cost 30832.3984375 nuclear_cost 54621.94921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.150
# it 5 cost=52334.59375 data_cost 24500.2421875 nuclear_cost 55668.703125
# 	time_data=0.004 time_regs=0.001 time_prox=0.129
# it 6 cost=48082.0546875 data_cost 19801.48046875 nuclear_cost 56561.1484375
# 	time_data=0.003 time_regs=0.001 time_prox=0.151
# it 7 cost=44952.7421875 data_cost 16331.119140625 nuclear_cost 57243.25
# 	time_data=0.005 time_regs=0.001 time_prox=0.178
# it 8 cost=42155.2734375 data_cost 13718.548828125 nuclear_cost 56873.4453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 9 cost=40264.77734375 data_cost 11779.078125 nuclear_cost 56971.3984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 10 cost=39087.0078125 data_cost 10292.265625 nuclear_cost 57589.484375
# 	time_data=0.004 time_regs=0.001 time_prox=0.195
# it 11 cost=38575.8828125 data_cost 9091.578125 nuclear_cost 58968.60546875
# 	time_data=0.004 time_regs=0.001 time_prox=0.184
# it 12 cost=36271.84375 data_cost 8048.259765625 nuclear_cost 56447.16796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.182
# it 13 cost=35717.03515625 data_cost 7205.71142578125 nuclear_cost 57022.6484375
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 14 cost=34488.85546875 data_cost 6504.22265625 nuclear_cost 55969.265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.182
# it 15 cost=32470.9140625 data_cost 5927.89892578125 nuclear_cost 53086.03125
# 	time_data=0.004 time_regs=0.001 time_prox=0.188
# it 16 cost=32202.859375 data_cost 5457.2275390625 nuclear_cost 53491.265625
# 	time_data=0.004 time_regs=0.001 time_prox=0.174
# it 17 cost=31130.75 data_cost 5056.39892578125 nuclear_cost 52148.703125
# 	time_data=0.005 time_regs=0.001 time_prox=0.146
# it 18 cost=30368.587890625 data_cost 4713.826171875 nuclear_cost 51309.5234375
# 	time_data=0.004 time_regs=0.001 time_prox=0.124
# it 19 cost=30508.41015625 data_cost 4426.75341796875 nuclear_cost 52163.3125
# 	time_data=0.004 time_regs=0.001 time_prox=0.123
# it 20 cost=28570.1171875 data_cost 4121.0478515625 nuclear_cost 48898.140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 21 cost=28419.052734375 data_cost 3891.375244140625 nuclear_cost 49055.35546875
# 	time_data=0.004 time_regs=0.001 time_prox=0.147
# it 22 cost=27686.6796875 data_cost 3654.1220703125 nuclear_cost 48065.1171875
# 	time_data=0.004 time_regs=0.001 time_prox=0.155
# it 23 cost=27738.19921875 data_cost 3427.304931640625 nuclear_cost 48621.7890625
# 	time_data=0.004 time_regs=0.001 time_prox=0.150
# it 24 cost=26322.4609375 data_cost 3225.33642578125 nuclear_cost 46194.25
# 	time_data=0.003 time_regs=0.001 time_prox=0.194
# it 25 cost=26241.197265625 data_cost 3075.196533203125 nuclear_cost 46332.0
# 	time_data=0.004 time_regs=0.001 time_prox=0.187
# it 26 cost=25830.171875 data_cost 2932.6357421875 nuclear_cost 45795.0703125
# 	time_data=0.003 time_regs=0.002 time_prox=0.181
# it 27 cost=25318.056640625 data_cost 2795.424072265625 nuclear_cost 45045.265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.190
# it 28 cost=25095.1640625 data_cost 2664.32666015625 nuclear_cost 44861.67578125
# 	time_data=0.005 time_regs=0.001 time_prox=0.195
# it 29 cost=24359.60546875 data_cost 2545.436767578125 nuclear_cost 43628.3359375
# 	time_data=0.004 time_regs=0.001 time_prox=0.191
# it 30 cost=24846.912109375 data_cost 2447.28466796875 nuclear_cost 44799.25390625
# 	time_data=0.004 time_regs=0.001 time_prox=0.187
# it 31 cost=24278.552734375 data_cost 2321.024169921875 nuclear_cost 43915.05859375
# 	time_data=0.004 time_regs=0.001 time_prox=0.186
# it 32 cost=23671.884765625 data_cost 2196.103759765625 nuclear_cost 42951.5625
# 	time_data=0.008 time_regs=0.001 time_prox=0.175
# it 33 cost=23318.455078125 data_cost 2100.797119140625 nuclear_cost 42435.31640625
# 	time_data=0.004 time_regs=0.001 time_prox=0.180
# it 34 cost=22897.53125 data_cost 2036.1214599609375 nuclear_cost 41722.8203125
# 	time_data=0.004 time_regs=0.001 time_prox=0.161
# it 35 cost=22821.408203125 data_cost 1968.197021484375 nuclear_cost 41706.421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.121
# it 36 cost=23012.37109375 data_cost 1903.2109375 nuclear_cost 42218.3203125
# 	time_data=0.004 time_regs=0.001 time_prox=0.115
# it 37 cost=22554.796875 data_cost 1843.445556640625 nuclear_cost 41422.703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.114
# it 38 cost=22557.078125 data_cost 1797.3154296875 nuclear_cost 41519.5234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.116
# it 39 cost=22471.103515625 data_cost 1751.665771484375 nuclear_cost 41438.875
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 40 cost=22329.078125 data_cost 1711.937255859375 nuclear_cost 41234.28125
# 	time_data=0.003 time_regs=0.001 time_prox=0.125
# it 41 cost=22514.888671875 data_cost 1681.6759033203125 nuclear_cost 41666.42578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 42 cost=22181.06640625 data_cost 1630.734130859375 nuclear_cost 41100.6640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 43 cost=22169.341796875 data_cost 1582.977294921875 nuclear_cost 41172.73046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.192
# it 44 cost=21885.5625 data_cost 1547.468017578125 nuclear_cost 40676.1875
# 	time_data=0.004 time_regs=0.001 time_prox=0.178
# it 45 cost=21540.1484375 data_cost 1517.0908203125 nuclear_cost 40046.1171875
# 	time_data=0.004 time_regs=0.001 time_prox=0.188
# it 46 cost=21713.701171875 data_cost 1497.9996337890625 nuclear_cost 40431.40234375
# 	time_data=0.004 time_regs=0.001 time_prox=0.186
# it 47 cost=21690.166015625 data_cost 1478.1339111328125 nuclear_cost 40424.0625
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 48 cost=21507.16015625 data_cost 1461.5224609375 nuclear_cost 40091.2734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.121
# it 49 cost=21920.5625 data_cost 1455.425048828125 nuclear_cost 40930.2734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.131
# it 50 cost=21518.3984375 data_cost 1449.8006591796875 nuclear_cost 40137.1953125
# 	time_data=0.005 time_regs=0.002 time_prox=0.137
# it 51 cost=21818.794921875 data_cost 1444.133056640625 nuclear_cost 40749.32421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.130
# it 52 cost=21648.064453125 data_cost 1439.3204345703125 nuclear_cost 40417.48828125
# 	time_data=0.003 time_regs=0.001 time_prox=0.132
# it 53 cost=21487.779296875 data_cost 1433.0250244140625 nuclear_cost 40109.5078125
# 	time_data=0.003 time_regs=0.001 time_prox=0.150
# it 54 cost=21349.03515625 data_cost 1426.21533203125 nuclear_cost 39845.640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.135
# it 55 cost=21394.779296875 data_cost 1422.3172607421875 nuclear_cost 39944.92578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.156
# it 56 cost=21708.40625 data_cost 1421.5224609375 nuclear_cost 40573.765625
# 	time_data=0.004 time_regs=0.001 time_prox=0.160
# it 57 cost=21471.85546875 data_cost 1424.52587890625 nuclear_cost 40094.66015625
# 	time_data=0.005 time_regs=0.001 time_prox=0.159
# it 58 cost=21418.4609375 data_cost 1426.8985595703125 nuclear_cost 39983.125
# 	time_data=0.005 time_regs=0.001 time_prox=0.182
# it 59 cost=21359.2734375 data_cost 1430.1400146484375 nuclear_cost 39858.265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 60 cost=21553.65625 data_cost 1432.597900390625 nuclear_cost 40242.1171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 61 cost=21644.947265625 data_cost 1432.024658203125 nuclear_cost 40425.84375
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 62 cost=21295.1328125 data_cost 1429.7022705078125 nuclear_cost 39730.859375
# 	time_data=0.004 time_regs=0.001 time_prox=0.181
# it 63 cost=21370.58984375 data_cost 1425.870361328125 nuclear_cost 39889.4375
# 	time_data=0.003 time_regs=0.001 time_prox=0.262
# it 64 cost=21497.484375 data_cost 1425.956787109375 nuclear_cost 40143.0546875
# 	time_data=0.018 time_regs=0.001 time_prox=0.199
# it 65 cost=21628.970703125 data_cost 1425.8499755859375 nuclear_cost 40406.2421875
# 	time_data=0.005 time_regs=0.001 time_prox=0.171
# it 66 cost=21625.927734375 data_cost 1427.0965576171875 nuclear_cost 40397.6640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 67 cost=21226.46484375 data_cost 1432.72607421875 nuclear_cost 39587.4765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 68 cost=21159.037109375 data_cost 1440.064208984375 nuclear_cost 39437.9453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.182
# it 69 cost=21407.18359375 data_cost 1446.116455078125 nuclear_cost 39922.1328125
# 	time_data=0.004 time_regs=0.001 time_prox=0.181
# Elapsed 12.069984197616577
# Mem:  763.03076171875 1365.87890625 602.84814453125
# it 0 cost=98248.9375 data_cost 74720.375 nuclear_cost 47057.125
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 1 cost=86067.59375 data_cost 61454.8125 nuclear_cost 49225.5703125
# 	time_data=0.004 time_regs=0.001 time_prox=0.181
# it 2 cost=74764.984375 data_cost 49187.9765625 nuclear_cost 51154.0078125
# 	time_data=0.003 time_regs=0.001 time_prox=0.182
# it 3 cost=65236.984375 data_cost 38817.19140625 nuclear_cost 52839.5859375
# 	time_data=0.004 time_regs=0.001 time_prox=0.189
# it 4 cost=57840.125 data_cost 30588.03125 nuclear_cost 54504.1875
# 	time_data=0.005 time_regs=0.001 time_prox=0.206
# it 5 cost=52279.140625 data_cost 24248.56640625 nuclear_cost 56061.15234375
# 	time_data=0.004 time_regs=0.001 time_prox=0.196
# it 6 cost=47808.91796875 data_cost 19564.326171875 nuclear_cost 56489.18359375
# 	time_data=0.004 time_regs=0.001 time_prox=0.183
# it 7 cost=45230.83984375 data_cost 16115.859375 nuclear_cost 58229.9609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 8 cost=42726.16796875 data_cost 13527.3525390625 nuclear_cost 58397.6328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.181
# it 9 cost=41023.50390625 data_cost 11594.1474609375 nuclear_cost 58858.71484375
# 	time_data=0.003 time_regs=0.001 time_prox=0.175
# it 10 cost=38779.2109375 data_cost 10086.423828125 nuclear_cost 57385.578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 11 cost=37524.72265625 data_cost 8936.7421875 nuclear_cost 57175.9609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 12 cost=36754.12890625 data_cost 7972.96240234375 nuclear_cost 57562.33203125
# 	time_data=0.003 time_regs=0.001 time_prox=0.144
# it 13 cost=35351.58203125 data_cost 7167.6083984375 nuclear_cost 56367.9453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.119
# it 14 cost=34160.42578125 data_cost 6495.5068359375 nuclear_cost 55329.8359375
# 	time_data=0.004 time_regs=0.001 time_prox=0.138
# it 15 cost=33700.4453125 data_cost 5958.154296875 nuclear_cost 55484.578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.109
# it 16 cost=32424.12109375 data_cost 5462.4033203125 nuclear_cost 53923.4375
# 	time_data=0.003 time_regs=0.001 time_prox=0.112
# it 17 cost=31773.28125 data_cost 5051.0400390625 nuclear_cost 53444.484375
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 18 cost=30740.17578125 data_cost 4682.5478515625 nuclear_cost 52115.2578125
# 	time_data=0.004 time_regs=0.001 time_prox=0.171
# it 19 cost=30159.96484375 data_cost 4390.0478515625 nuclear_cost 51539.83203125
# 	time_data=0.003 time_regs=0.001 time_prox=0.185
# it 20 cost=29175.3671875 data_cost 4116.4091796875 nuclear_cost 50117.9140625
# 	time_data=0.004 time_regs=0.001 time_prox=0.170
# it 21 cost=28549.169921875 data_cost 3858.686279296875 nuclear_cost 49380.96875
# 	time_data=0.003 time_regs=0.001 time_prox=0.151
# it 22 cost=28328.76953125 data_cost 3640.23291015625 nuclear_cost 49377.07421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.122
# it 23 cost=27156.83203125 data_cost 3438.5498046875 nuclear_cost 47436.56640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.143
# it 24 cost=27150.103515625 data_cost 3261.091796875 nuclear_cost 47778.0234375
# 	time_data=0.004 time_regs=0.001 time_prox=0.130
# it 25 cost=26437.708984375 data_cost 3090.96240234375 nuclear_cost 46693.4921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.143
# it 26 cost=25906.2109375 data_cost 2946.3505859375 nuclear_cost 45919.71875
# 	time_data=0.003 time_regs=0.001 time_prox=0.144
# it 27 cost=25531.44921875 data_cost 2811.1962890625 nuclear_cost 45440.5078125
# 	time_data=0.003 time_regs=0.001 time_prox=0.148
# it 28 cost=25116.45703125 data_cost 2702.572509765625 nuclear_cost 44827.76953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.148
# it 29 cost=25126.591796875 data_cost 2573.93994140625 nuclear_cost 45105.3046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.148
# it 30 cost=24447.44140625 data_cost 2449.09814453125 nuclear_cost 43996.6875
# 	time_data=0.003 time_regs=0.001 time_prox=0.144
# it 31 cost=24197.333984375 data_cost 2352.385009765625 nuclear_cost 43689.8984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 32 cost=24020.84375 data_cost 2257.9541015625 nuclear_cost 43525.78125
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 33 cost=23607.919921875 data_cost 2174.94580078125 nuclear_cost 42865.94921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.179
# it 34 cost=23866.791015625 data_cost 2092.642578125 nuclear_cost 43548.296875
# 	time_data=0.004 time_regs=0.001 time_prox=0.188
# it 35 cost=23429.548828125 data_cost 2010.88427734375 nuclear_cost 42837.328125
# 	time_data=0.004 time_regs=0.001 time_prox=0.168
# it 36 cost=23368.935546875 data_cost 1941.22412109375 nuclear_cost 42855.421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 37 cost=22451.59375 data_cost 1880.5621337890625 nuclear_cost 41142.0625
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 38 cost=22717.16796875 data_cost 1834.9027099609375 nuclear_cost 41764.53125
# 	time_data=0.004 time_regs=0.001 time_prox=0.187
# it 39 cost=23070.30859375 data_cost 1803.7060546875 nuclear_cost 42533.203125
# 	time_data=0.005 time_regs=0.001 time_prox=0.181
# it 40 cost=22455.38671875 data_cost 1757.9857177734375 nuclear_cost 41394.80078125
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 41 cost=22614.62109375 data_cost 1722.2578125 nuclear_cost 41784.7265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 42 cost=22241.97265625 data_cost 1682.6873779296875 nuclear_cost 41118.5703125
# 	time_data=0.004 time_regs=0.001 time_prox=0.188
# it 43 cost=22394.05078125 data_cost 1654.3111572265625 nuclear_cost 41479.48046875
# 	time_data=0.005 time_regs=0.001 time_prox=0.183
# it 44 cost=22435.029296875 data_cost 1625.6314697265625 nuclear_cost 41618.796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 45 cost=22153.615234375 data_cost 1600.560302734375 nuclear_cost 41106.109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 46 cost=21846.375 data_cost 1588.8568115234375 nuclear_cost 40515.03515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.175
# it 47 cost=22259.388671875 data_cost 1573.947998046875 nuclear_cost 41370.8828125
# 	time_data=0.004 time_regs=0.001 time_prox=0.120
# it 48 cost=22016.4609375 data_cost 1559.4776611328125 nuclear_cost 40913.96484375
# 	time_data=0.004 time_regs=0.001 time_prox=0.114
# it 49 cost=21900.041015625 data_cost 1548.677734375 nuclear_cost 40702.7265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.119
# it 50 cost=21892.478515625 data_cost 1540.0284423828125 nuclear_cost 40704.8984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.125
# it 51 cost=21967.9140625 data_cost 1529.642578125 nuclear_cost 40876.54296875
# 	time_data=0.003 time_regs=0.001 time_prox=0.129
# it 52 cost=21731.771484375 data_cost 1526.74560546875 nuclear_cost 40410.05078125
# 	time_data=0.005 time_regs=0.004 time_prox=0.134
# it 53 cost=21779.69140625 data_cost 1520.373291015625 nuclear_cost 40518.63671875
# 	time_data=0.003 time_regs=0.001 time_prox=0.147
# it 54 cost=21914.23046875 data_cost 1512.2659912109375 nuclear_cost 40803.9296875
# 	time_data=0.004 time_regs=0.001 time_prox=0.123
# it 55 cost=21977.185546875 data_cost 1510.614013671875 nuclear_cost 40933.14453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.169
# it 56 cost=21749.46484375 data_cost 1510.668212890625 nuclear_cost 40477.59375
# 	time_data=0.006 time_regs=0.001 time_prox=0.168
# it 57 cost=21462.44140625 data_cost 1509.59375 nuclear_cost 39905.6953125
# 	time_data=0.004 time_regs=0.001 time_prox=0.188
# it 58 cost=21993.302734375 data_cost 1507.021728515625 nuclear_cost 40972.5625
# 	time_data=0.005 time_regs=0.002 time_prox=0.185
# it 59 cost=21581.158203125 data_cost 1507.54931640625 nuclear_cost 40147.21875
# 	time_data=0.005 time_regs=0.002 time_prox=0.183
# it 60 cost=21879.181640625 data_cost 1510.48828125 nuclear_cost 40737.38671875
# 	time_data=0.003 time_regs=0.001 time_prox=0.185
# it 61 cost=21589.501953125 data_cost 1514.2855224609375 nuclear_cost 40150.43359375
# 	time_data=0.004 time_regs=0.001 time_prox=0.184
# it 62 cost=21567.81640625 data_cost 1520.2623291015625 nuclear_cost 40095.109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.181
# it 63 cost=21430.720703125 data_cost 1526.7994384765625 nuclear_cost 39807.84375
# 	time_data=0.004 time_regs=0.001 time_prox=0.169
# it 64 cost=21737.41796875 data_cost 1528.2318115234375 nuclear_cost 40418.37109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 65 cost=21350.484375 data_cost 1531.677978515625 nuclear_cost 39637.61328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 66 cost=21899.865234375 data_cost 1538.147216796875 nuclear_cost 40723.4375
# 	time_data=0.004 time_regs=0.001 time_prox=0.165
# it 67 cost=21889.669921875 data_cost 1539.27197265625 nuclear_cost 40700.796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.129
# it 68 cost=21838.0 data_cost 1538.674072265625 nuclear_cost 40598.65234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.135
# it 69 cost=21728.494140625 data_cost 1536.7630615234375 nuclear_cost 40383.4609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.134
# Elapsed 11.931082010269165
# Mem:  763.03076171875 1365.87890625 602.84814453125

# %%
# complex -> (mag, flow)
mag_gt, flow_gt = complex2magflow(img, venc=np.array(VENC))
mag_csllr, flow_csllr = complex2magflow(img_csllr, venc=np.array(VENC))

# %%
# shapes: (Nv, Nt, SPE, PE, FE)
showz = 14  # SPE index
showt = 1   # Nt index
showv = 0   # magnitude uses this v-index when Nv>1

row, col = 3, 4
fig, axes = plt.subplots(row, col, figsize=(20, 15), constrained_layout=False)
fig.suptitle(
    f"CSLLR Reconstruction Results (US Rate: {usrate}x, λ_TV={lamb_tv}, λ_LLR={lamb_llr})",
    fontsize=14, fontweight="bold"
)

# ---------------- Row 1: GT ----------------
ax = axes[0, 0]
im = ax.imshow(
    np.abs(mag_gt[showv, showt, showz]).T,
    cmap="gray", origin="lower", aspect="auto"
)
ax.set_title("Magnitude GT", fontsize=11, fontweight="bold")
ax.set_xlabel("FE"); ax.set_ylabel("PE")
fig.colorbar(im, ax=ax, fraction=0.046)

for i in range(3):
    ax = axes[0, i + 1]
    img2d = flow_gt[i, showt, showz].T.astype(np.float32)  # no segmask for velocity
    im = ax.imshow(
        img2d,
        cmap="gray", origin="lower", aspect="auto",
        vmin=-VENC[i], vmax=VENC[i]
    )
    ax.set_title(f"Velocity GT ({VOrder[i]})", fontsize=11, fontweight="bold")
    ax.set_xlabel("FE"); ax.set_ylabel("PE")
    fig.colorbar(im, ax=ax, fraction=0.046)

# ---------------- Row 2: CSLLR ----------------
ax = axes[1, 0]
im = ax.imshow(
    np.abs(mag_csllr[showv, showt, showz]).T,
    cmap="gray", origin="lower", aspect="auto"
)
ax.set_title("Magnitude CS-LLR", fontsize=11, fontweight="bold")
ax.set_xlabel("FE"); ax.set_ylabel("PE")
fig.colorbar(im, ax=ax, fraction=0.046)

for i in range(3):
    ax = axes[1, i + 1]
    img2d = flow_csllr[i, showt, showz].T.astype(np.float32)  # no segmask for velocity
    im = ax.imshow(
        img2d,
        cmap="gray", origin="lower", aspect="auto",
        vmin=-VENC[i], vmax=VENC[i]
    )
    ax.set_title(f"Velocity CS-LLR ({VOrder[i]})", fontsize=11, fontweight="bold")
    ax.set_xlabel("FE"); ax.set_ylabel("PE")
    fig.colorbar(im, ax=ax, fraction=0.046)

# ---------------- Row 3: Difference maps ----------------
# Magnitude difference, masked
mag_diff = np.abs(np.abs(mag_csllr) - np.abs(mag_gt))[showv, showt, showz]
ax = axes[2, 0]
im = ax.imshow(
    (mag_diff * segmask[showz]).T,
    cmap="gray", origin="lower", aspect="auto"
)
ax.set_title("Magnitude Difference", fontsize=11, fontweight="bold")
ax.set_xlabel("FE"); ax.set_ylabel("PE")
fig.colorbar(im, ax=ax, fraction=0.046)

# Velocity difference, masked
for i in range(3):
    ax = axes[2, i + 1]
    flow_diff = np.abs(flow_csllr - flow_gt)[i, showt, showz] * segmask[showz]
    im = ax.imshow(
        flow_diff.T.astype(np.float32),
        cmap="gray", origin="lower", aspect="auto",
        vmin=0, vmax=VENC[i] / 3
    )
    ax.set_title(f"Velocity Difference ({VOrder[i]})", fontsize=11, fontweight="bold")
    ax.set_xlabel("FE"); ax.set_ylabel("PE")
    fig.colorbar(im, ax=ax, fraction=0.046)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
