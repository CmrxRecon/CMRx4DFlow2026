# %%
import sys
sys.path.append('../')
from CMRx4DFlowMaskGeneration import *
from Utils import *
from einops import rearrange
import matplotlib.pyplot as plt

# %%
# Read one subject/case from a directory containing the corresponding .mat files
data_dir = '/mnt/nas/nas3/openData/rawdata/4dFlow/ChallengeData/DemoData'

# `load_mat` takes the .mat file path and variable name (`key`) as input.
# It returns a lazy HDF5-like handle (h5py-style): data is not loaded into memory
# until you index it.
kdata_full = load_mat(data_dir + '/kdata_full.mat', key='kdata_full')
coilmap    = load_mat(data_dir + '/coilmap.mat',    key='coilmap')
segmask    = load_mat(data_dir + '/segmask.mat',    key='segmask')
params     = read_params_csv(data_dir + '/params.csv')

# Use [()] to materialize the entire dataset into RAM as a NumPy array.
kdata_full = kdata_full[()]
coilmap    = coilmap[()]
segmask    = segmask[()]

Nv, Nt, Nc, SPE, PE, FE = kdata_full.shape

VENC = params['VENC']
VOrder = params['venc_order']

# %%
img = np.sum(k2i_numpy(kdata_full, ax=[-1, -2, -3]) * np.conj(coilmap), axis=-4)

# %%
usrate = 10  # Desired undersampling factor (e.g., 10x)

# Target number of sampled k-space locations per 2D (PE, SPE) frame
total_points = PE * SPE // usrate

# fun_mask_gen_2d expects mask_size = (width, height) = (PE, SPE)
mask_size = (PE, SPE)

# Gaussian sampling density parameters:
sigma_x = PE / 5
sigma_y = SPE / 5

# Generate one undersampling mask per time frame.
# Output shape: (SPE, PE, Nt)
masks_spe_pe_t = fun_mask_gen_2d(
    mask_size=mask_size,
    total_points=total_points,
    pattern_num=Nt,
    sigma_x=sigma_x,
    sigma_y=sigma_y,
)

# Reshape to the expected tensor layout:
# (SPE, PE, Nt) -> (1, Nt, 1, SPE, PE, 1)
usmask = rearrange(masks_spe_pe_t, "spe pe t -> 1 t 1 spe pe 1")

# Empirical undersampling factor from the sampling density:
# mean(usmask) is the fraction of sampled points, so 1/mean is the effective acceleration.
actual_usrate = 1.0 / np.mean(usmask)
print(f"Mask shape: {usmask.shape}, Actual undersampling rate: {actual_usrate:.2f}x")

# --- Visualization ---
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle(
    f"Undersampling Mask (Target: {usrate}x, Actual: {actual_usrate:.2f}x)",
    fontsize=14,
    fontweight="bold",
)

# Panel 1: a single time-frame mask, displayed as (PE, SPE) for readability
im0 = axes[0].imshow(usmask[0, 0, 0, :, :, 0].T, cmap="gray")
axes[0].set_xlabel("PE", fontsize=12)
axes[0].set_ylabel("SPE", fontsize=12)
axes[0].set_title("Single-Frame Mask", fontsize=12)
plt.colorbar(im0, ax=axes[0], fraction=0.046)

# Panel 2: temporal evolution for a fixed SPE line (middle SPE index).
# Shows (PE vs time) sampling pattern at that SPE location.
im1 = axes[1].imshow(usmask[0, :, 0, SPE // 2, :, 0].T, cmap="gray")
axes[1].set_xlabel("PE", fontsize=12)
axes[1].set_ylabel("Time frame (Nt)", fontsize=12)
axes[1].set_title(f"Temporal Variation (fixed SPE={SPE // 2})", fontsize=12)
plt.colorbar(im1, ax=axes[1], fraction=0.046)

plt.tight_layout()
plt.show()
# Out:
# Mask shape: (1, 12, 1, 39, 160, 1), Actual undersampling rate: 10.00x

# %% [markdown]
# The image \(X\) can be reconstructed from undersampled multi-coil k-space measurements \(y\) by solving a regularized inverse problem:
#
# $$
# \hat{X}
# = \arg\min_{X}\;
# \frac{1}{2}\bigl\lVert \mathcal{A}(X) - y \bigr\rVert_2^2
# \;+\;
# \lambda_{\mathrm{llr}} \sum_{i\in\Omega} \bigl\lVert \mathcal{P}_i(X) \bigr\rVert_*
# \;+\;
# \lambda_{\mathrm{TV}} \,\lVert X \rVert_{\mathrm{TV}}.
# $$
#
# **Symbol definitions:**
# - $\hat{X}$: The reconstructed image (`img_csllr`).
# - $y$: Undersampled multi-coil k-space measurements.
# - $\mathcal{A}(\cdot)$: The forward encoding operator that maps an image $X$ to undersampled multi-coil k-space. In this demo, it is the composition of coil sensitivity modulation, FFT, and application of the undersampling mask, i.e.,
#   $$
#   \mathcal{A}(X) = \mathbf{U}\mathcal{F}\mathbf{C}X,
#   $$
#   where $\mathbf{C}$ applies the coil sensitivity maps, $\mathcal{F}$ is the FFT, and $\mathbf{U}$ is the undersampling mask.
# - $\lambda_{\mathrm{llr}}$: Weight for locally low-rank (LLR) regularization.
# - $\Omega$: Index set of local blocks/patches over which LLR is enforced.
# - $\mathcal{P}_i(\cdot)$: Patch/block extraction (and reshaping) operator that maps $X$ to the $i$-th local matrix.
# - $\lVert \cdot \rVert_*$: Nuclear norm.
# - $\lambda_{\mathrm{TV}}$: Weight for total variation (TV) regularization.
# - $\lVert X \rVert_{\mathrm{TV}}$: TV seminorm of $X$.

# %%
kdata_us = kdata_full * usmask
ksp = rearrange(kdata_us, 'nv nt nc spe pe fe -> nv nc nt fe pe spe')
coils = rearrange(coilmap, 'nc spe pe fe-> nc 1 fe pe spe')
# In this demo, we only use LLR regularization; therefore, we set lamb_tv = 0.0 (i.e., TV regularization is disabled).
lamb_tv = 0.0
lamb_llr = 0.5 
img_csllr = CS_LLR(lamb_tv, lamb_llr, ksp, coils, seg=True)
img_csllr = rearrange(img_csllr, 'nv nt fe pe spe -> nv nt spe pe fe')
# Out:
# /home/caory/miniconda3/envs/ryy/lib/python3.10/site-packages/torch/cuda/memory.py:491: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# /localhome/caory/CMRx4DFlow2026/CMRx4DFlowReconDemo/Utils/CS_LLR_utils.py:147: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   bsz = torch.tensor(bsz, dtype=torch.float32)
# /localhome/caory/CMRx4DFlow2026/CMRx4DFlowReconDemo/Utils/CS_LLR_utils.py:148: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(bsz * torch.ceil(imsz / bsz), dtype=torch.long)
# it 0 cost=103108.28125 data_cost 80470.8984375 nuclear_cost 45274.7734375
# 	time_data=0.104 time_regs=0.166 time_prox=0.102
# it 1 cost=89964.171875 data_cost 66274.390625 nuclear_cost 47379.5703125
# 	time_data=0.004 time_regs=0.001 time_prox=0.254
# it 2 cost=77465.75 data_cost 53051.265625 nuclear_cost 48828.97265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.250
# it 3 cost=67773.0859375 data_cost 41793.109375 nuclear_cost 51959.953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 4 cost=59534.1328125 data_cost 32768.4375 nuclear_cost 53531.38671875
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 5 cost=53539.609375 data_cost 25857.314453125 nuclear_cost 55364.5859375
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 6 cost=49057.97265625 data_cost 20695.955078125 nuclear_cost 56724.03515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.291
# it 7 cost=45274.8984375 data_cost 16919.783203125 nuclear_cost 56710.2265625
# 	time_data=0.004 time_regs=0.001 time_prox=0.247
# it 8 cost=43147.375 data_cost 14126.5087890625 nuclear_cost 58041.734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 9 cost=40999.953125 data_cost 12032.6787109375 nuclear_cost 57934.546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 10 cost=39002.171875 data_cost 10428.556640625 nuclear_cost 57147.234375
# 	time_data=0.004 time_regs=0.001 time_prox=0.226
# it 11 cost=37501.9765625 data_cost 9175.3955078125 nuclear_cost 56653.1640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 12 cost=36688.65625 data_cost 8204.77734375 nuclear_cost 56967.7578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.200
# it 13 cost=35622.1171875 data_cost 7356.89599609375 nuclear_cost 56530.44140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.205
# it 14 cost=33831.41015625 data_cost 6635.34765625 nuclear_cost 54392.125
# 	time_data=0.003 time_regs=0.001 time_prox=0.198
# it 15 cost=32931.5234375 data_cost 6069.43359375 nuclear_cost 53724.18359375
# 	time_data=0.003 time_regs=0.001 time_prox=0.203
# it 16 cost=32212.431640625 data_cost 5583.791015625 nuclear_cost 53257.28125
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 17 cost=31605.1015625 data_cost 5155.43994140625 nuclear_cost 52899.32421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.215
# it 18 cost=30711.607421875 data_cost 4759.505859375 nuclear_cost 51904.203125
# 	time_data=0.004 time_regs=0.001 time_prox=0.223
# it 19 cost=30302.55078125 data_cost 4443.0771484375 nuclear_cost 51718.9453125
# 	time_data=0.004 time_regs=0.001 time_prox=0.201
# it 20 cost=29053.107421875 data_cost 4152.23681640625 nuclear_cost 49801.7421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.210
# it 21 cost=28045.01171875 data_cost 3877.141357421875 nuclear_cost 48335.7421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.209
# it 22 cost=27262.544921875 data_cost 3656.243408203125 nuclear_cost 47212.6015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.208
# it 23 cost=26963.05078125 data_cost 3461.6064453125 nuclear_cost 47002.890625
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 24 cost=26689.919921875 data_cost 3283.52197265625 nuclear_cost 46812.796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.237
# it 25 cost=26830.03515625 data_cost 3103.612548828125 nuclear_cost 47452.84375
# 	time_data=0.009 time_regs=0.002 time_prox=0.199
# it 26 cost=26145.505859375 data_cost 2912.074951171875 nuclear_cost 46466.86328125
# 	time_data=0.004 time_regs=0.001 time_prox=0.213
# it 27 cost=25217.638671875 data_cost 2742.98291015625 nuclear_cost 44949.3125
# 	time_data=0.004 time_regs=0.001 time_prox=0.246
# it 28 cost=25364.08984375 data_cost 2606.211181640625 nuclear_cost 45515.7578125
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 29 cost=24341.455078125 data_cost 2472.198974609375 nuclear_cost 43738.51171875
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 30 cost=24490.18359375 data_cost 2350.1201171875 nuclear_cost 44280.125
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 31 cost=24072.8515625 data_cost 2238.721923828125 nuclear_cost 43668.2578125
# 	time_data=0.004 time_regs=0.001 time_prox=0.246
# it 32 cost=23529.814453125 data_cost 2139.259521484375 nuclear_cost 42781.109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.245
# it 33 cost=23243.2265625 data_cost 2050.1708984375 nuclear_cost 42386.109375
# 	time_data=0.004 time_regs=0.001 time_prox=0.246
# it 34 cost=22875.94140625 data_cost 1983.7818603515625 nuclear_cost 41784.3203125
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 35 cost=22939.19921875 data_cost 1915.5859375 nuclear_cost 42047.2265625
# 	time_data=0.004 time_regs=0.001 time_prox=0.250
# it 36 cost=22565.732421875 data_cost 1847.615966796875 nuclear_cost 41436.234375
# 	time_data=0.004 time_regs=0.001 time_prox=0.248
# it 37 cost=22426.34765625 data_cost 1786.6729736328125 nuclear_cost 41279.34765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 38 cost=21934.146484375 data_cost 1719.525390625 nuclear_cost 40429.2421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 39 cost=22066.88671875 data_cost 1663.87158203125 nuclear_cost 40806.03125
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 40 cost=22099.88671875 data_cost 1601.0897216796875 nuclear_cost 40997.59375
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 41 cost=21742.76171875 data_cost 1548.89453125 nuclear_cost 40387.734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 42 cost=21540.7421875 data_cost 1505.7193603515625 nuclear_cost 40070.046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 43 cost=21649.259765625 data_cost 1471.8533935546875 nuclear_cost 40354.8125
# 	time_data=0.004 time_regs=0.001 time_prox=0.245
# it 44 cost=21072.884765625 data_cost 1439.1263427734375 nuclear_cost 39267.515625
# 	time_data=0.004 time_regs=0.001 time_prox=0.251
# it 45 cost=21401.69140625 data_cost 1412.0673828125 nuclear_cost 39979.24609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 46 cost=20979.11328125 data_cost 1384.771484375 nuclear_cost 39188.68359375
# 	time_data=0.004 time_regs=0.001 time_prox=0.214
# it 47 cost=21564.89453125 data_cost 1361.285888671875 nuclear_cost 40407.21875
# 	time_data=0.003 time_regs=0.001 time_prox=0.126
# it 48 cost=21590.455078125 data_cost 1332.7664794921875 nuclear_cost 40515.37890625
# 	time_data=0.003 time_regs=0.001 time_prox=0.122
# it 49 cost=21711.9921875 data_cost 1308.991943359375 nuclear_cost 40806.0
# 	time_data=0.003 time_regs=0.001 time_prox=0.125
# it 50 cost=21562.61328125 data_cost 1287.918701171875 nuclear_cost 40549.390625
# 	time_data=0.003 time_regs=0.001 time_prox=0.128
# it 51 cost=21273.833984375 data_cost 1271.9053955078125 nuclear_cost 40003.85546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.134
# it 52 cost=21402.326171875 data_cost 1253.9632568359375 nuclear_cost 40296.7265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.129
# it 53 cost=21159.298828125 data_cost 1245.302978515625 nuclear_cost 39827.9921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.137
# it 54 cost=21217.916015625 data_cost 1237.3326416015625 nuclear_cost 39961.16796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.138
# it 55 cost=21232.712890625 data_cost 1232.4869384765625 nuclear_cost 40000.453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.157
# it 56 cost=21157.529296875 data_cost 1234.475830078125 nuclear_cost 39846.10546875
# 	time_data=0.004 time_regs=0.001 time_prox=0.153
# it 57 cost=21449.375 data_cost 1233.6199951171875 nuclear_cost 40431.51171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.172
# it 58 cost=21422.419921875 data_cost 1235.9114990234375 nuclear_cost 40373.015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 59 cost=21234.20703125 data_cost 1238.928955078125 nuclear_cost 39990.5546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 60 cost=21284.080078125 data_cost 1240.1002197265625 nuclear_cost 40087.9609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.176
# it 61 cost=21316.044921875 data_cost 1251.8817138671875 nuclear_cost 40128.328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.175
# it 62 cost=21268.494140625 data_cost 1265.571533203125 nuclear_cost 40005.84375
# 	time_data=0.003 time_regs=0.001 time_prox=0.176
# it 63 cost=21203.8515625 data_cost 1278.44091796875 nuclear_cost 39850.8203125
# 	time_data=0.003 time_regs=0.001 time_prox=0.175
# it 64 cost=21310.048828125 data_cost 1283.22412109375 nuclear_cost 40053.6484375
# 	time_data=0.003 time_regs=0.001 time_prox=0.177
# it 65 cost=21152.775390625 data_cost 1283.1859130859375 nuclear_cost 39739.1796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.192
# it 66 cost=21150.419921875 data_cost 1287.170654296875 nuclear_cost 39726.5
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 67 cost=21348.70703125 data_cost 1293.02783203125 nuclear_cost 40111.359375
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 68 cost=21309.138671875 data_cost 1298.6033935546875 nuclear_cost 40021.0703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 69 cost=21239.3203125 data_cost 1306.202880859375 nuclear_cost 39866.234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.252
# Elapsed 15.957537174224854
# Mem:  771.0693359375 1365.79248046875 594.72314453125
# it 0 cost=102509.40625 data_cost 79982.7734375 nuclear_cost 45053.2578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.328
# it 1 cost=89728.203125 data_cost 65903.328125 nuclear_cost 47649.74609375
# 	time_data=0.004 time_regs=0.001 time_prox=0.194
# it 2 cost=77442.8984375 data_cost 52798.93359375 nuclear_cost 49287.92578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.206
# it 3 cost=67487.109375 data_cost 41624.58984375 nuclear_cost 51725.046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.223
# it 4 cost=59120.3046875 data_cost 32678.3671875 nuclear_cost 52883.87109375
# 	time_data=0.004 time_regs=0.001 time_prox=0.196
# it 5 cost=53491.890625 data_cost 25800.505859375 nuclear_cost 55382.765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.194
# it 6 cost=48530.9296875 data_cost 20669.9609375 nuclear_cost 55721.9375
# 	time_data=0.004 time_regs=0.001 time_prox=0.206
# it 7 cost=45583.84375 data_cost 16921.14453125 nuclear_cost 57325.3984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.206
# it 8 cost=42836.53125 data_cost 14154.2666015625 nuclear_cost 57364.53125
# 	time_data=0.003 time_regs=0.001 time_prox=0.205
# it 9 cost=40582.18359375 data_cost 12089.62890625 nuclear_cost 56985.109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.202
# it 10 cost=39302.05859375 data_cost 10553.62109375 nuclear_cost 57496.875
# 	time_data=0.003 time_regs=0.001 time_prox=0.205
# it 11 cost=38201.6171875 data_cost 9322.1171875 nuclear_cost 57759.0
# 	time_data=0.003 time_regs=0.001 time_prox=0.208
# it 12 cost=37054.4375 data_cost 8280.0078125 nuclear_cost 57548.859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.199
# it 13 cost=35188.9453125 data_cost 7395.23193359375 nuclear_cost 55587.4296875
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 14 cost=33743.53515625 data_cost 6697.1669921875 nuclear_cost 54092.734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.203
# it 15 cost=33924.8671875 data_cost 6165.71923828125 nuclear_cost 55518.296875
# 	time_data=0.003 time_regs=0.001 time_prox=0.224
# it 16 cost=32519.708984375 data_cost 5634.75 nuclear_cost 53769.91796875
# 	time_data=0.005 time_regs=0.002 time_prox=0.285
# it 17 cost=31584.45703125 data_cost 5207.060546875 nuclear_cost 52754.79296875
# 	time_data=0.031 time_regs=0.005 time_prox=0.212
# it 18 cost=30617.5078125 data_cost 4840.365234375 nuclear_cost 51554.28515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 19 cost=30245.1640625 data_cost 4541.30029296875 nuclear_cost 51407.7265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 20 cost=29498.98046875 data_cost 4230.8818359375 nuclear_cost 50536.1953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 21 cost=28893.513671875 data_cost 3976.949462890625 nuclear_cost 49833.12890625
# 	time_data=0.004 time_regs=0.001 time_prox=0.247
# it 22 cost=27935.8125 data_cost 3733.49658203125 nuclear_cost 48404.6328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 23 cost=27566.166015625 data_cost 3554.642333984375 nuclear_cost 48023.046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 24 cost=27026.34765625 data_cost 3357.43017578125 nuclear_cost 47337.8359375
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 25 cost=26675.3671875 data_cost 3197.363037109375 nuclear_cost 46956.0078125
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 26 cost=26248.56640625 data_cost 3025.13818359375 nuclear_cost 46446.85546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.252
# it 27 cost=25570.1796875 data_cost 2843.8486328125 nuclear_cost 45452.6640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.250
# it 28 cost=25210.984375 data_cost 2718.50390625 nuclear_cost 44984.9609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 29 cost=24510.81640625 data_cost 2602.18310546875 nuclear_cost 43817.265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 30 cost=24128.275390625 data_cost 2491.030029296875 nuclear_cost 43274.4921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.185
# it 31 cost=24028.89453125 data_cost 2402.445556640625 nuclear_cost 43252.8984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.186
# it 32 cost=24317.87109375 data_cost 2315.1826171875 nuclear_cost 44005.37890625
# 	time_data=0.003 time_regs=0.001 time_prox=0.193
# it 33 cost=23578.349609375 data_cost 2215.76416015625 nuclear_cost 42725.171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.188
# it 34 cost=23086.154296875 data_cost 2123.093505859375 nuclear_cost 41926.12109375
# 	time_data=0.004 time_regs=0.001 time_prox=0.209
# it 35 cost=23553.3359375 data_cost 2049.515380859375 nuclear_cost 43007.640625
# 	time_data=0.004 time_regs=0.001 time_prox=0.175
# it 36 cost=23224.8359375 data_cost 1967.577392578125 nuclear_cost 42514.515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.192
# it 37 cost=22967.384765625 data_cost 1897.685302734375 nuclear_cost 42139.3984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.191
# it 38 cost=22713.36328125 data_cost 1830.9559326171875 nuclear_cost 41764.81640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.189
# it 39 cost=22408.77734375 data_cost 1773.51806640625 nuclear_cost 41270.51953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.197
# it 40 cost=22240.314453125 data_cost 1725.372802734375 nuclear_cost 41029.8828125
# 	time_data=0.003 time_regs=0.001 time_prox=0.194
# it 41 cost=21748.83984375 data_cost 1681.859619140625 nuclear_cost 40133.9609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.195
# it 42 cost=22217.357421875 data_cost 1641.904052734375 nuclear_cost 41150.90625
# 	time_data=0.003 time_regs=0.001 time_prox=0.188
# it 43 cost=22174.578125 data_cost 1603.4249267578125 nuclear_cost 41142.3046875
# 	time_data=0.004 time_regs=0.001 time_prox=0.192
# it 44 cost=22048.849609375 data_cost 1569.8353271484375 nuclear_cost 40958.02734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.250
# it 45 cost=21462.806640625 data_cost 1546.630859375 nuclear_cost 39832.3515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 46 cost=21660.865234375 data_cost 1519.69287109375 nuclear_cost 40282.34375
# 	time_data=0.003 time_regs=0.001 time_prox=0.315
# it 47 cost=21599.8515625 data_cost 1500.69970703125 nuclear_cost 40198.3046875
# 	time_data=0.008 time_regs=0.002 time_prox=0.236
# it 48 cost=21268.248046875 data_cost 1483.3607177734375 nuclear_cost 39569.7734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.274
# it 49 cost=21114.22265625 data_cost 1469.3095703125 nuclear_cost 39289.828125
# 	time_data=0.006 time_regs=0.002 time_prox=0.257
# it 50 cost=21503.22265625 data_cost 1455.4339599609375 nuclear_cost 40095.578125
# 	time_data=0.005 time_regs=0.002 time_prox=0.264
# it 51 cost=21609.017578125 data_cost 1434.8001708984375 nuclear_cost 40348.43359375
# 	time_data=0.007 time_regs=0.001 time_prox=0.242
# it 52 cost=21738.591796875 data_cost 1419.041748046875 nuclear_cost 40639.1015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.195
# it 53 cost=21761.97265625 data_cost 1407.14599609375 nuclear_cost 40709.65234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.200
# it 54 cost=21770.806640625 data_cost 1395.354248046875 nuclear_cost 40750.90625
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 55 cost=21599.40625 data_cost 1386.3292236328125 nuclear_cost 40426.15234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.200
# it 56 cost=21450.3828125 data_cost 1381.044189453125 nuclear_cost 40138.67578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.206
# it 57 cost=21730.33984375 data_cost 1379.54541015625 nuclear_cost 40701.58984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.206
# it 58 cost=21683.658203125 data_cost 1382.8326416015625 nuclear_cost 40601.65234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 59 cost=21348.0859375 data_cost 1387.5537109375 nuclear_cost 39921.06640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.207
# it 60 cost=21439.826171875 data_cost 1390.0252685546875 nuclear_cost 40099.6015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.206
# it 61 cost=21495.029296875 data_cost 1393.3592529296875 nuclear_cost 40203.33984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.205
# it 62 cost=21390.86328125 data_cost 1400.8651123046875 nuclear_cost 39979.99609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.215
# it 63 cost=21519.177734375 data_cost 1405.9422607421875 nuclear_cost 40226.47265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.208
# it 64 cost=21599.240234375 data_cost 1413.965576171875 nuclear_cost 40370.55078125
# 	time_data=0.003 time_regs=0.001 time_prox=0.205
# it 65 cost=21489.869140625 data_cost 1421.21630859375 nuclear_cost 40137.3046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.206
# it 66 cost=21627.146484375 data_cost 1425.455322265625 nuclear_cost 40403.3828125
# 	time_data=0.003 time_regs=0.001 time_prox=0.202
# it 67 cost=21414.556640625 data_cost 1430.244873046875 nuclear_cost 39968.625
# 	time_data=0.003 time_regs=0.001 time_prox=0.212
# it 68 cost=21505.16796875 data_cost 1438.421142578125 nuclear_cost 40133.4921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.242
# it 69 cost=21493.744140625 data_cost 1444.18505859375 nuclear_cost 40099.1171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.189
# Elapsed 16.220525979995728
# Mem:  763.03076171875 1365.87890625 602.84814453125
# it 0 cost=102661.6171875 data_cost 80005.7265625 nuclear_cost 45311.78125
# 	time_data=0.003 time_regs=0.001 time_prox=0.228
# it 1 cost=89595.3984375 data_cost 65970.578125 nuclear_cost 47249.64453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 2 cost=77543.953125 data_cost 52880.92578125 nuclear_cost 49326.0625
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 3 cost=67444.171875 data_cost 41706.65625 nuclear_cost 51475.0234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.171
# it 4 cost=59360.0703125 data_cost 32742.716796875 nuclear_cost 53234.7109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.170
# it 5 cost=53137.3515625 data_cost 25893.984375 nuclear_cost 54486.73046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.174
# it 6 cost=48897.078125 data_cost 20811.474609375 nuclear_cost 56171.203125
# 	time_data=0.003 time_regs=0.001 time_prox=0.159
# it 7 cost=45889.01171875 data_cost 17003.05078125 nuclear_cost 57771.921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.119
# it 8 cost=42815.1015625 data_cost 14168.05859375 nuclear_cost 57294.0859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.120
# it 9 cost=41051.99609375 data_cost 12102.8994140625 nuclear_cost 57898.1953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.118
# it 10 cost=39296.1875 data_cost 10480.904296875 nuclear_cost 57630.56640625
# 	time_data=0.003 time_regs=0.001 time_prox=0.124
# it 11 cost=37067.14453125 data_cost 9238.0654296875 nuclear_cost 55658.15625
# 	time_data=0.004 time_regs=0.001 time_prox=0.155
# it 12 cost=37324.546875 data_cost 8305.8203125 nuclear_cost 58037.453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.202
# it 13 cost=35746.65234375 data_cost 7415.39208984375 nuclear_cost 56662.5234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.203
# it 14 cost=34394.09765625 data_cost 6707.2861328125 nuclear_cost 55373.625
# 	time_data=0.003 time_regs=0.001 time_prox=0.199
# it 15 cost=33503.08984375 data_cost 6126.72265625 nuclear_cost 54752.734375
# 	time_data=0.004 time_regs=0.001 time_prox=0.202
# it 16 cost=32290.93359375 data_cost 5620.21142578125 nuclear_cost 53341.4453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 17 cost=31628.453125 data_cost 5204.765625 nuclear_cost 52847.375
# 	time_data=0.003 time_regs=0.001 time_prox=0.199
# it 18 cost=30456.11328125 data_cost 4844.35595703125 nuclear_cost 51223.515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.203
# it 19 cost=29970.703125 data_cost 4523.5712890625 nuclear_cost 50894.265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 20 cost=28949.6015625 data_cost 4252.6708984375 nuclear_cost 49393.859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 21 cost=28530.7734375 data_cost 3996.133544921875 nuclear_cost 49069.28125
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 22 cost=28499.72265625 data_cost 3764.2431640625 nuclear_cost 49470.9609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 23 cost=27444.033203125 data_cost 3535.861572265625 nuclear_cost 47816.34375
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 24 cost=27027.40234375 data_cost 3347.26513671875 nuclear_cost 47360.2734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.257
# it 25 cost=26131.09375 data_cost 3171.5859375 nuclear_cost 45919.015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.251
# it 26 cost=26283.52734375 data_cost 3027.3369140625 nuclear_cost 46512.37890625
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 27 cost=25791.14453125 data_cost 2883.973388671875 nuclear_cost 45814.34375
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 28 cost=25296.169921875 data_cost 2757.382568359375 nuclear_cost 45077.57421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.248
# it 29 cost=24660.02734375 data_cost 2601.8388671875 nuclear_cost 44116.375
# 	time_data=0.003 time_regs=0.001 time_prox=0.261
# it 30 cost=24331.169921875 data_cost 2491.826171875 nuclear_cost 43678.6875
# 	time_data=0.005 time_regs=0.002 time_prox=0.243
# it 31 cost=24131.83984375 data_cost 2400.19970703125 nuclear_cost 43463.28125
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 32 cost=23475.978515625 data_cost 2291.415771484375 nuclear_cost 42369.125
# 	time_data=0.004 time_regs=0.001 time_prox=0.247
# it 33 cost=23554.580078125 data_cost 2211.85888671875 nuclear_cost 42685.44140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.224
# it 34 cost=23530.666015625 data_cost 2115.299072265625 nuclear_cost 42830.734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.200
# it 35 cost=23164.4140625 data_cost 2023.9404296875 nuclear_cost 42280.94921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.208
# it 36 cost=23501.912109375 data_cost 1952.3426513671875 nuclear_cost 43099.140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.203
# it 37 cost=22548.677734375 data_cost 1865.2174072265625 nuclear_cost 41366.921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 38 cost=22696.265625 data_cost 1797.97607421875 nuclear_cost 41796.578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.198
# it 39 cost=22272.669921875 data_cost 1750.046875 nuclear_cost 41045.24609375
# 	time_data=0.003 time_regs=0.001 time_prox=0.206
# it 40 cost=22054.509765625 data_cost 1702.8853759765625 nuclear_cost 40703.25
# 	time_data=0.003 time_regs=0.001 time_prox=0.213
# it 41 cost=21757.791015625 data_cost 1658.947265625 nuclear_cost 40197.6875
# 	time_data=0.003 time_regs=0.001 time_prox=0.224
# it 42 cost=21582.22265625 data_cost 1624.5479736328125 nuclear_cost 39915.34765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.220
# it 43 cost=21959.35546875 data_cost 1598.3880615234375 nuclear_cost 40721.93359375
# 	time_data=0.004 time_regs=0.001 time_prox=0.227
# it 44 cost=21875.109375 data_cost 1560.87451171875 nuclear_cost 40628.46875
# 	time_data=0.005 time_regs=0.002 time_prox=0.217
# it 45 cost=22044.00390625 data_cost 1530.230712890625 nuclear_cost 41027.546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.210
# it 46 cost=21742.802734375 data_cost 1504.427001953125 nuclear_cost 40476.75
# 	time_data=0.003 time_regs=0.001 time_prox=0.218
# it 47 cost=21704.615234375 data_cost 1479.9591064453125 nuclear_cost 40449.3125
# 	time_data=0.003 time_regs=0.001 time_prox=0.208
# it 48 cost=21972.28515625 data_cost 1462.3206787109375 nuclear_cost 41019.9296875
# 	time_data=0.003 time_regs=0.001 time_prox=0.204
# it 49 cost=21572.162109375 data_cost 1444.480712890625 nuclear_cost 40255.36328125
# 	time_data=0.004 time_regs=0.001 time_prox=0.248
# it 50 cost=21489.30078125 data_cost 1431.167724609375 nuclear_cost 40116.265625
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 51 cost=21702.515625 data_cost 1417.8353271484375 nuclear_cost 40569.359375
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 52 cost=21230.62109375 data_cost 1403.9144287109375 nuclear_cost 39653.4140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 53 cost=21286.365234375 data_cost 1393.9635009765625 nuclear_cost 39784.8046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.255
# it 54 cost=21307.3984375 data_cost 1388.4638671875 nuclear_cost 39837.8671875
# 	time_data=0.003 time_regs=0.001 time_prox=0.250
# it 55 cost=21659.080078125 data_cost 1383.4183349609375 nuclear_cost 40551.32421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.252
# it 56 cost=21262.845703125 data_cost 1380.260009765625 nuclear_cost 39765.171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 57 cost=21486.939453125 data_cost 1380.1322021484375 nuclear_cost 40213.61328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 58 cost=21632.62890625 data_cost 1385.4188232421875 nuclear_cost 40494.421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.248
# it 59 cost=21510.310546875 data_cost 1386.45458984375 nuclear_cost 40247.7109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.268
# it 60 cost=21587.2265625 data_cost 1385.586181640625 nuclear_cost 40403.28125
# 	time_data=0.006 time_regs=0.004 time_prox=0.241
# it 61 cost=21660.943359375 data_cost 1386.920654296875 nuclear_cost 40548.046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 62 cost=21491.115234375 data_cost 1392.6629638671875 nuclear_cost 40196.90625
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 63 cost=21450.9375 data_cost 1400.94580078125 nuclear_cost 40099.984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 64 cost=21472.412109375 data_cost 1407.3631591796875 nuclear_cost 40130.09765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 65 cost=21358.919921875 data_cost 1411.923095703125 nuclear_cost 39893.9921875
# 	time_data=0.004 time_regs=0.001 time_prox=0.246
# it 66 cost=21365.15625 data_cost 1418.2894287109375 nuclear_cost 39893.734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 67 cost=21327.353515625 data_cost 1423.217529296875 nuclear_cost 39808.2734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.257
# it 68 cost=21698.12890625 data_cost 1426.290771484375 nuclear_cost 40543.67578125
# 	time_data=0.004 time_regs=0.001 time_prox=0.211
# it 69 cost=21465.4765625 data_cost 1431.105712890625 nuclear_cost 40068.7421875
# 	time_data=0.004 time_regs=0.001 time_prox=0.197
# Elapsed 16.18068265914917
# Mem:  763.03076171875 1365.87890625 602.84814453125
# it 0 cost=102056.9609375 data_cost 79409.8203125 nuclear_cost 45294.27734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.263
# it 1 cost=89179.7421875 data_cost 65440.57421875 nuclear_cost 47478.3359375
# 	time_data=0.003 time_regs=0.001 time_prox=0.205
# it 2 cost=77027.8046875 data_cost 52439.9453125 nuclear_cost 49175.71875
# 	time_data=0.003 time_regs=0.001 time_prox=0.202
# it 3 cost=67442.1015625 data_cost 41378.65625 nuclear_cost 52126.890625
# 	time_data=0.004 time_regs=0.001 time_prox=0.200
# it 4 cost=58927.5546875 data_cost 32474.32421875 nuclear_cost 52906.45703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.208
# it 5 cost=53324.4453125 data_cost 25703.021484375 nuclear_cost 55242.8515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 6 cost=48378.875 data_cost 20623.025390625 nuclear_cost 55511.6953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 7 cost=44976.46875 data_cost 16928.685546875 nuclear_cost 56095.5625
# 	time_data=0.003 time_regs=0.001 time_prox=0.207
# it 8 cost=43416.296875 data_cost 14242.2734375 nuclear_cost 58348.046875
# 	time_data=0.004 time_regs=0.001 time_prox=0.236
# it 9 cost=41217.7421875 data_cost 12130.7529296875 nuclear_cost 58173.9765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 10 cost=39741.2265625 data_cost 10516.990234375 nuclear_cost 58448.4765625
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 11 cost=37751.0703125 data_cost 9247.48046875 nuclear_cost 57007.1796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 12 cost=36928.86328125 data_cost 8246.095703125 nuclear_cost 57365.53515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 13 cost=35201.21875 data_cost 7414.92578125 nuclear_cost 55572.58203125
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 14 cost=34860.71875 data_cost 6767.783203125 nuclear_cost 56185.875
# 	time_data=0.003 time_regs=0.001 time_prox=0.223
# it 15 cost=33908.73046875 data_cost 6177.70849609375 nuclear_cost 55462.046875
# 	time_data=0.003 time_regs=0.001 time_prox=0.185
# it 16 cost=32785.93359375 data_cost 5662.5380859375 nuclear_cost 54246.7890625
# 	time_data=0.004 time_regs=0.002 time_prox=0.171
# it 17 cost=31469.220703125 data_cost 5242.02490234375 nuclear_cost 52454.390625
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 18 cost=31095.2578125 data_cost 4909.703125 nuclear_cost 52371.109375
# 	time_data=0.003 time_regs=0.001 time_prox=0.173
# it 19 cost=30480.244140625 data_cost 4589.39208984375 nuclear_cost 51781.703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.183
# it 20 cost=29683.09765625 data_cost 4278.4677734375 nuclear_cost 50809.2578125
# 	time_data=0.004 time_regs=0.001 time_prox=0.172
# it 21 cost=28426.552734375 data_cost 4029.31884765625 nuclear_cost 48794.46875
# 	time_data=0.003 time_regs=0.001 time_prox=0.154
# it 22 cost=28278.169921875 data_cost 3835.060546875 nuclear_cost 48886.21875
# 	time_data=0.003 time_regs=0.001 time_prox=0.120
# it 23 cost=28026.921875 data_cost 3635.50146484375 nuclear_cost 48782.83984375
# 	time_data=0.003 time_regs=0.001 time_prox=0.119
# it 24 cost=27195.025390625 data_cost 3427.75146484375 nuclear_cost 47534.546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.122
# it 25 cost=26802.51953125 data_cost 3246.8798828125 nuclear_cost 47111.28125
# 	time_data=0.003 time_regs=0.001 time_prox=0.128
# it 26 cost=26302.419921875 data_cost 3063.876708984375 nuclear_cost 46477.0859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.125
# it 27 cost=25809.8671875 data_cost 2917.02783203125 nuclear_cost 45785.6796875
# 	time_data=0.004 time_regs=0.001 time_prox=0.196
# it 28 cost=25825.9375 data_cost 2781.341552734375 nuclear_cost 46089.19140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 29 cost=25281.005859375 data_cost 2632.105224609375 nuclear_cost 45297.80078125
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 30 cost=24900.287109375 data_cost 2511.122802734375 nuclear_cost 44778.328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.199
# it 31 cost=24584.572265625 data_cost 2405.80712890625 nuclear_cost 44357.53125
# 	time_data=0.010 time_regs=0.001 time_prox=0.199
# it 32 cost=24044.41796875 data_cost 2307.00048828125 nuclear_cost 43474.8359375
# 	time_data=0.006 time_regs=0.001 time_prox=0.198
# it 33 cost=23909.974609375 data_cost 2237.70556640625 nuclear_cost 43344.5390625
# 	time_data=0.003 time_regs=0.001 time_prox=0.228
# it 34 cost=23539.26953125 data_cost 2151.296875 nuclear_cost 42775.9453125
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 35 cost=23226.240234375 data_cost 2082.59619140625 nuclear_cost 42287.2890625
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 36 cost=23062.322265625 data_cost 2017.15966796875 nuclear_cost 42090.32421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.253
# it 37 cost=22837.921875 data_cost 1960.9061279296875 nuclear_cost 41754.03125
# 	time_data=0.003 time_regs=0.001 time_prox=0.250
# it 38 cost=22588.8984375 data_cost 1918.80908203125 nuclear_cost 41340.1796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 39 cost=23070.529296875 data_cost 1870.5892333984375 nuclear_cost 42399.87890625
# 	time_data=0.003 time_regs=0.001 time_prox=0.249
# it 40 cost=22381.5625 data_cost 1811.71533203125 nuclear_cost 41139.6953125
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 41 cost=22472.830078125 data_cost 1769.476318359375 nuclear_cost 41406.70703125
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 42 cost=22193.494140625 data_cost 1723.00927734375 nuclear_cost 40940.96875
# 	time_data=0.004 time_regs=0.001 time_prox=0.244
# it 43 cost=22338.2109375 data_cost 1687.0460205078125 nuclear_cost 41302.328125
# 	time_data=0.003 time_regs=0.001 time_prox=0.246
# it 44 cost=22313.830078125 data_cost 1650.25048828125 nuclear_cost 41327.16015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 45 cost=22209.384765625 data_cost 1613.8314208984375 nuclear_cost 41191.10546875
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 46 cost=22295.638671875 data_cost 1583.326171875 nuclear_cost 41424.625
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 47 cost=21949.146484375 data_cost 1557.221435546875 nuclear_cost 40783.8515625
# 	time_data=0.003 time_regs=0.001 time_prox=0.261
# it 48 cost=21722.251953125 data_cost 1532.1612548828125 nuclear_cost 40380.1796875
# 	time_data=0.004 time_regs=0.001 time_prox=0.191
# it 49 cost=21719.3359375 data_cost 1514.1412353515625 nuclear_cost 40410.390625
# 	time_data=0.003 time_regs=0.001 time_prox=0.220
# it 50 cost=22221.6953125 data_cost 1495.966552734375 nuclear_cost 41451.45703125
# 	time_data=0.007 time_regs=0.003 time_prox=0.225
# it 51 cost=21691.705078125 data_cost 1472.985595703125 nuclear_cost 40437.4375
# 	time_data=0.012 time_regs=0.004 time_prox=0.182
# it 52 cost=21931.720703125 data_cost 1465.3292236328125 nuclear_cost 40932.78125
# 	time_data=0.003 time_regs=0.001 time_prox=0.192
# it 53 cost=21913.962890625 data_cost 1457.762451171875 nuclear_cost 40912.40234375
# 	time_data=0.003 time_regs=0.001 time_prox=0.198
# it 54 cost=21931.05078125 data_cost 1452.24951171875 nuclear_cost 40957.6015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 55 cost=21763.091796875 data_cost 1447.7987060546875 nuclear_cost 40630.5859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 56 cost=22071.234375 data_cost 1448.1453857421875 nuclear_cost 41246.1796875
# 	time_data=0.003 time_regs=0.001 time_prox=0.198
# it 57 cost=21914.498046875 data_cost 1445.5416259765625 nuclear_cost 40937.9140625
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 58 cost=21795.994140625 data_cost 1448.8565673828125 nuclear_cost 40694.2734375
# 	time_data=0.003 time_regs=0.001 time_prox=0.200
# it 59 cost=21856.19921875 data_cost 1446.7388916015625 nuclear_cost 40818.921875
# 	time_data=0.003 time_regs=0.001 time_prox=0.197
# it 60 cost=21995.97265625 data_cost 1454.1019287109375 nuclear_cost 41083.7421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 61 cost=21857.552734375 data_cost 1459.8907470703125 nuclear_cost 40795.32421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.201
# it 62 cost=21887.361328125 data_cost 1468.58203125 nuclear_cost 40837.55859375
# 	time_data=0.003 time_regs=0.001 time_prox=0.213
# it 63 cost=21757.28125 data_cost 1475.014892578125 nuclear_cost 40564.53125
# 	time_data=0.003 time_regs=0.001 time_prox=0.247
# it 64 cost=21736.5390625 data_cost 1479.453125 nuclear_cost 40514.171875
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 65 cost=21752.830078125 data_cost 1487.030029296875 nuclear_cost 40531.6015625
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 66 cost=21739.94140625 data_cost 1491.2935791015625 nuclear_cost 40497.296875
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# it 67 cost=21766.26171875 data_cost 1499.0504150390625 nuclear_cost 40534.421875
# 	time_data=0.003 time_regs=0.001 time_prox=0.261
# it 68 cost=21543.564453125 data_cost 1506.364501953125 nuclear_cost 40074.3984375
# 	time_data=0.006 time_regs=0.002 time_prox=0.245
# it 69 cost=21847.419921875 data_cost 1514.5418701171875 nuclear_cost 40665.7578125
# 	time_data=0.003 time_regs=0.001 time_prox=0.248
# Elapsed 15.747495174407959
# Mem:  763.03076171875 1365.87890625 602.84814453125

# %%
# complex -> (mag, flow)
mag_gt, flow_gt = complex2magflow(img, venc=np.array(VENC))
mag_csllr, flow_csllr = complex2magflow(img_csllr, venc=np.array(VENC))

# %%
# shapes: (Nv, Nt, SPE, PE, FE)
showz = 14  # SPE index
showt = 1   # Nt index
showv = 0   # magnitude uses this v-index when Nv>1

row, col = 3, 4
fig, axes = plt.subplots(row, col, figsize=(20, 15), constrained_layout=False)
fig.suptitle(
    f"CSLLR Reconstruction Results (US Rate: {usrate}x, λ_TV={lamb_tv}, λ_LLR={lamb_llr})",
    fontsize=14, fontweight="bold"
)

# ---------------- Row 1: GT ----------------
ax = axes[0, 0]
im = ax.imshow(
    np.abs(mag_gt[showv, showt, showz]).T,
    cmap="gray", origin="lower", aspect="auto"
)
ax.set_title("Magnitude GT", fontsize=11, fontweight="bold")
ax.set_xlabel("FE"); ax.set_ylabel("PE")
fig.colorbar(im, ax=ax, fraction=0.046)

for i in range(3):
    ax = axes[0, i + 1]
    img2d = flow_gt[i, showt, showz].T.astype(np.float32)  # no segmask for velocity
    im = ax.imshow(
        img2d,
        cmap="gray", origin="lower", aspect="auto",
        vmin=-VENC[i], vmax=VENC[i]
    )
    ax.set_title(f"Velocity GT ({VOrder[i]})", fontsize=11, fontweight="bold")
    ax.set_xlabel("FE"); ax.set_ylabel("PE")
    fig.colorbar(im, ax=ax, fraction=0.046)

# ---------------- Row 2: CSLLR ----------------
ax = axes[1, 0]
im = ax.imshow(
    np.abs(mag_csllr[showv, showt, showz]).T,
    cmap="gray", origin="lower", aspect="auto"
)
ax.set_title("Magnitude CS-LLR", fontsize=11, fontweight="bold")
ax.set_xlabel("FE"); ax.set_ylabel("PE")
fig.colorbar(im, ax=ax, fraction=0.046)

for i in range(3):
    ax = axes[1, i + 1]
    img2d = flow_csllr[i, showt, showz].T.astype(np.float32)  # no segmask for velocity
    im = ax.imshow(
        img2d,
        cmap="gray", origin="lower", aspect="auto",
        vmin=-VENC[i], vmax=VENC[i]
    )
    ax.set_title(f"Velocity CS-LLR ({VOrder[i]})", fontsize=11, fontweight="bold")
    ax.set_xlabel("FE"); ax.set_ylabel("PE")
    fig.colorbar(im, ax=ax, fraction=0.046)

# ---------------- Row 3: Difference maps ----------------
# Magnitude difference, masked
mag_diff = np.abs(np.abs(mag_csllr) - np.abs(mag_gt))[showv, showt, showz]
ax = axes[2, 0]
im = ax.imshow(
    (mag_diff * segmask[showz]).T,
    cmap="gray", origin="lower", aspect="auto"
)
ax.set_title("Magnitude Difference", fontsize=11, fontweight="bold")
ax.set_xlabel("FE"); ax.set_ylabel("PE")
fig.colorbar(im, ax=ax, fraction=0.046)

# Velocity difference, masked
for i in range(3):
    ax = axes[2, i + 1]
    flow_diff = np.abs(flow_csllr - flow_gt)[i, showt, showz] * segmask[showz]
    im = ax.imshow(
        flow_diff.T.astype(np.float32),
        cmap="gray", origin="lower", aspect="auto",
        vmin=0, vmax=VENC[i] / 3
    )
    ax.set_title(f"Velocity Difference ({VOrder[i]})", fontsize=11, fontweight="bold")
    ax.set_xlabel("FE"); ax.set_ylabel("PE")
    fig.colorbar(im, ax=ax, fraction=0.046)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
